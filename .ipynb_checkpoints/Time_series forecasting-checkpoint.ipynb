# %%
# import necessary packages
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import pmdarima as pm
from prophet import Prophet
from pylab import rcParams
from itertools import product
from tqdm import tqdm_notebook

# %%
# loading the data - data is provided in excel format
xls = pd.ExcelFile('data_file.xlsx')

# %%
# read the data in WaterWorksData sheet and read the right  columns and rows
df1 = pd.read_excel(xls, 'WaterWorksData',skiprows=[1,2,3,4,5],names=['date','yvw','cww','sew','t','r','total'])
df1['date']=pd.to_datetime(df1.date,format="%Y-%m-%d")
df1.head()
# Out:
#         date  yvw  cww  sew     t    r  total
# 0 2007-01-01  427  234  392  29.0  0.4   1053
# 1 2007-01-02  372  208  345  28.0  0.0    925
# 2 2007-01-03  469  285  414  30.0  0.0   1168
# 3 2007-01-04  491  294  443  33.0  0.0   1228
# 4 2007-01-05  437  295  424  34.0  0.0   1156

# %%
# get basic statistics of the data, here the yvw,cww and sew are three different entitities which records the water 
# consumption in those areas, total consumption would be the summation of all, t - max temperature andr - rainfall
df1.describe()
# Out:
#                yvw          cww          sew            t            r  \
# count  4905.000000  4905.000000  4905.000000  4905.000000  4905.000000
# mean    402.954740   282.638328   389.996126    21.048909     1.733007
# std      68.027304    40.424194    63.353930     7.311028     5.112720
# min     245.000000   137.000000   218.000000     7.300000     0.000000
# 25%     357.000000   253.000000   343.000000    15.100000     0.000000
# 50%     384.000000   277.000000   377.000000    19.800000     0.000000
# 75%     431.000000   303.000000   419.000000    25.800000     1.000000
# max     778.000000   478.000000   700.000000    45.000000   106.000000
#
#              total
# count  4905.000000
# mean   1075.589195
# std     166.953176
# min     754.000000
# 25%     955.000000
# 50%    1039.000000
# 75%    1148.000000
# max    1941.000000

# %%
# validate the trend is stationary or non stationary
# H0-non stationary, H1-stationary
result=adfuller(df1.total)
print('ADF Statistics: %f'%result[0])
print('p-value: %f'%result[1])
# Out:
# ADF Statistics: -4.118709
# p-value: 0.000902

# %%
# failed to reject H1 at 95% confidence interval

# %%
# just see the trend
df1.plot(x='date',y='total',figsize=(16,12))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Prepare data for FBprophet model
df_day=df1[['date','total']].copy()
# dff.reset_index(inplace=True)
df_day.columns=['ds','y']
df_day.head()
# Out:
#           ds     y
# 0 2007-01-01  1053
# 1 2007-01-02   925
# 2 2007-01-03  1168
# 3 2007-01-04  1228
# 4 2007-01-05  1156

# %%
# get the monthly data
df_monthly = df1.copy()
df_monthly=df_monthly.resample('MS', on='date').sum()
# df_monthly.index = [df_monthly.index.min()] + list(df_monthly.index[1:])
df_monthly.reset_index(inplace=True)
df_monthly=df_monthly[['date','total']]
df_monthly.columns=['ds','y']
df_monthly.head()
# Out:
#           ds      y
# 0 2007-01-01  35016
# 1 2007-02-01  33816
# 2 2007-03-01  33940
# 3 2007-04-01  29517
# 4 2007-05-01  28862

# %%
# get only last 3 years data
m = Prophet()
m.fit(df_day[(df_day.ds>'2015-01-01')&(df_day.ds<'2020-05-01')])
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# future = m.make_future_dataframe(periods=30)
# future.tail()

future = m.make_future_dataframe(periods=31)
fcst = m.predict(future)
fig = m.plot(fcst)

# %%
# m.plot_components(fcst)
f=fcst[['ds','yhat','yhat_lower','yhat_upper']]
f=f[((f.ds>'2020-05-01')&(f.ds<'2020-06-01'))]
f['y']=df_day[((df_day.ds>'2020-05-01')&(df_day.ds<'2020-06-01'))].y.values
f.set_index('ds',inplace=True)

# %%
plt.figure(figsize=(12,10))
plt.plot(f.yhat*1.07)
# plt.plot(pred, color='darkgreen')
# plt.plot(f.yhat[-nd:]*.89, color='red')
plt.plot(f.y, color='red')
plt.fill_between(f.index, 
                 f.yhat_lower, 
                 f.yhat_upper, 
                 color='k', alpha=.15)
plt.show()

# %%
f['mae']=abs(f.y-f.yhat*1.07)
f['mse']=(f.y-f.yhat*1.07)**2
print(f.mae.mean(),f.mse.mean())
# Out:
# 33.069686945394494 1667.2110699035363

# %%
# let's try to predict monthly
m_train=df_monthly[((df_monthly.ds>'2012-01-01')&(df_monthly.ds<'2019-01-01'))]
m_test=df_monthly[((df_monthly.ds>'2019-01-01')&(df_monthly.ds<'2020-01-01'))]

# %%
m=Prophet(seasonality_mode='multiplicative')
m.fit(m_train)
future=m.make_future_dataframe(periods=12,freq='MS')
forecast=m.predict(future)



fm=forecast[['ds','yhat','yhat_lower','yhat_upper']]
fm=fm[((fm.ds>'2019-01-01')&(fm.ds<'2020-01-01'))]
fm['y']=m_test.y.values
fm.set_index('ds',inplace=True)

plt.figure(figsize=(12,10))
plt.plot(fm.yhat)
# plt.plot(pred, color='darkgreen')
# plt.plot(f.yhat[-nd:]*.89, color='red')
plt.plot(fm.y, color='red')
plt.fill_between(fm.index, 
                 fm.yhat_lower, 
                 fm.yhat_upper, 
                 color='k', alpha=.15)
plt.show()
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fm['mae']=abs(fm.y-fm.yhat*1.07)
fm['mse']=(fm.y-fm.yhat*1.07)**2
print(fm.mae.mean(),fm.mse.mean())
# Out:
# 2254.3981303672745 6376777.360848761

# %%
fm
# Out:
#                     yhat    yhat_lower    yhat_upper      y          mae  \
# ds
# 2019-02-01  39508.899553  37926.321370  41275.021527  39532  2742.522521
# 2019-03-01  41556.775504  39974.009376  43287.736831  44272   193.749789
# 2019-04-01  35465.783253  33870.551697  37275.779686  37104   844.388081
# 2019-05-01  34859.895444  33041.733935  36582.306151  35018  2282.088125
# 2019-06-01  32293.244147  30571.960103  34048.005507  32612  1941.771237
# 2019-07-01  33239.279054  31419.844850  34968.811920  32725  2841.028588
# 2019-08-01  33106.815338  31411.189943  34764.743637  32926  2498.292411
# 2019-09-01  32314.190331  30459.028048  34161.703201  31802  2774.183654
# 2019-10-01  37914.802005  36270.278432  39607.664207  35736  4832.838145
# 2019-11-01  35967.212502  34171.215557  37878.778192  36309  2175.917377
# 2019-12-01  41840.747202  40145.928681  43709.129337  43098  1671.599506
#
#                      mse
# ds
# 2019-02-01  7.521430e+06
# 2019-03-01  3.753898e+04
# 2019-04-01  7.129912e+05
# 2019-05-01  5.207926e+06
# 2019-06-01  3.770476e+06
# 2019-07-01  8.071443e+06
# 2019-08-01  6.241465e+06
# 2019-09-01  7.696095e+06
# 2019-10-01  2.335632e+07
# 2019-11-01  4.734616e+06
# 2019-12-01  2.794245e+06
